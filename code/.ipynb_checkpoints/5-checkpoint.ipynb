# %% [markdown]
# ### Linear regression from scratch using OLS

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import copy
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
train_data=pd.read_csv('/Users/pushpakumar/Downloads/cs-215-assignment-3-multiple-variate-regression/train.csv')
# test_data=pd.read_csv('/Users/pushpakumar/Downloads/cs-215-assignment-3-multiple-variate-regression/test.csv')

# %%
train_corr=train_data.corr()
target = 'yield'
correlation_with_target = train_corr[target]
low_corr_threshold = 0.15
low_corr_features = correlation_with_target[abs(correlation_with_target) < low_corr_threshold].index.tolist()
train_data = train_data.drop(columns=low_corr_features)
x= train_data.drop(columns='yield').values
y = train_data['yield'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# Visualize the data using scatter plot and histogram
sns.set_palette('colorblind')
sns.pairplot(data=train_data)

# %%
### note input x and y should be panda df

class Multiple_linear_regression():
    def __init__(self):
        self.coefficients=None
        self.intercept=None
        
    def fit(self,x,y):
        x=self.transform_x(x)
        y=self.transform_y(y)
        betas=self.estimate_coefficients(x,y)
        self.intercept=betas[0]
        self.coefficients=betas[1:]

            
    def predict(self, x):
        ## y = b_0 + b_1*x + ... + b_i*x_i
        prediction = np.dot(x, self.coefficients) + self.intercept
        return prediction
    
    def r2_score(self, y_true, y_pred):
        '''
            r2 = 1 - (rss/tss)
            rss = sum_{i=0}^{n} (y_i - y_hat)^2
            tss = sum_{i=0}^{n} (y_i - y_bar)^2
        '''
        y_values=y_true
        y_avg=np.mean(y_values)
        
        residual_sum_of_squares=0
        total_sum_of_squares=0
        for i in range(len(y_values)):
            residual_sum_of_squares+=(y_values[i]-y_pred[i])**2
            total_sum_of_squares+=(y_values[i]-y_avg)**2
            
        return 1-(residual_sum_of_squares/total_sum_of_squares)
    
    def transform_x(self, x):
        return np.hstack((np.ones((x.shape[0], 1)), x))
    def transform_y(self,y):
        return y
    def estimate_coefficients(self,x,y):
        # (x'x)^-1 x'y 
        xT=x.transpose()
        inversed=np.linalg.inv(xT.dot(x))
        coefficients=inversed.dot(xT).dot(y) 
        return coefficients

# %%
mlr=Multiple_linear_regression()
mlr.fit(x_train,y_train)
prediction=mlr.predict(x_test)
score=mlr.r2_score(y_test,prediction)
print(score)
# Out:
# 0.9158423465668505

# %%
class Nadaraya_watson_kernel_guassian():
    def __init__(self,bandwidth=1.0):
        self.bandwidth=bandwidth
        self.x_data=None
        self.y_data=None
    def fit(self,x,y):
        self.x_data=np.array(x)
        self.y_data=np.array(y)
    def gaussian_kernel(self,x):
        ## (1/2*pi) e^{-x^2 / 2}
        exponent=np.exp(-0.5 * (x**2))
        result=exponent/np.sqrt(2*np.pi)
        return result
    
    def predict(self, x):
        # n,m=x.shape
        temp = (x - self.x_data) / self.bandwidth
        distance_from_origin=np.linalg.norm(temp,axis=1)
        ker = self.gaussian_kernel(distance_from_origin)
        num = np.sum(ker * self.y_data)
        den = np.sum(ker)
        return num / den           
    
    def risk_function(self, x, y):
        # x is prediction y is actual 
        return abs(y - x)

# %%
h_x=np.linspace(0,1,300)
prediction=[]
risk=[]
for i in h_x:
    mlr2=Nadaraya_watson_kernel_guassian(i)
    mlr2.fit(x_train,y_train)
    risk_temp=0
    for j in range(len(x_test)):
        temp=mlr2.predict(x_test[j])
        risk_temp+=mlr2.risk_function(temp,y_test[j])
        prediction.append(temp)
    risk.append(risk_temp/len(x_test))
plt.plot(h_x,risk)
# Out:
# /var/folders/hz/gjlv0lbd4ds7shs1th30424c0000gp/T/ipykernel_48923/3837692474.py:17: RuntimeWarning: divide by zero encountered in divide
#   temp = (x - self.x_data) / self.bandwidth
# /var/folders/hz/gjlv0lbd4ds7shs1th30424c0000gp/T/ipykernel_48923/3837692474.py:17: RuntimeWarning: invalid value encountered in divide
#   temp = (x - self.x_data) / self.bandwidth
# /var/folders/hz/gjlv0lbd4ds7shs1th30424c0000gp/T/ipykernel_48923/3837692474.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   return num / den

# %%
h=0.15
mlr2=Nadaraya_watson_kernel_guassian(h)
mlr2.fit(x_train,y_train)
prediction=[]
for i in range(len(x_test)):
    temp=mlr2.predict(x_test[i])
    prediction.append(temp)
    
print(prediction[0:15])

print(y_test[0:15])
# Out:
# [6970.511646252523, 5222.845368368959, 7689.305963974101, 6066.015172060831, 6164.495465768606, 7417.610009669323, 5922.047005731643, 6857.054113303396, 6870.305958237998, 7165.988580202984, 7344.917285463302, 5347.017710007626, 5700.495185534575, 5198.165158371114, 7297.245256843262]
# [7897.9319  5914.16491 7732.22522 6595.45629 5729.71505 7888.41493
#  5199.79211 6626.50685 6880.7759  6869.7776  7440.71201 5377.27086
#  5203.87681 4853.8076  7529.17505]

# %%
plt.scatter(y_test,prediction)

# %%
np.corrcoef(y_test,prediction)
# Out:
# array([[1.        , 0.93353723],
#        [0.93353723, 1.        ]])
